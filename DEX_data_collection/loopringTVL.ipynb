# %%
import pandas as pd
import numpy as np
import time
import requests
import datetime as dt

pd.set_option('display.max_columns', None)

# %% [markdown]
# 6-Month Average TVL

# %%
#DefiLlama https://defillama.com/protocols/dexes 
lma = pd.read_csv("https://api.llama.fi/dataset/loopring.csv")

# %%
lma
# Out:
#      Unnamed: 0        Date     Timestamp            Loopring  \
# 0           NaN         NaN           NaN               Dexes
# 1           NaN         NaN           NaN            ethereum
# 2           NaN         NaN           NaN                 TVL
# 3           NaN         NaN           NaN                 NaN
# 4           NaN  30/08/2020  1.598746e+09   16911034.80409584
# ..          ...         ...           ...                 ...
# 753         NaN  18/09/2022  1.663459e+09  149317293.68511936
# 754         NaN  19/09/2022  1.663546e+09  140402690.54627365
# 755         NaN  20/09/2022  1.663632e+09  141568688.84341565
# 756         NaN  21/09/2022  1.663718e+09  139202235.88281885
# 757         NaN  22/09/2022  1.663805e+09  133931070.80164133
#
#              Loopring.1          Loopring.2          Loopring.3  \
# 0                 Dexes               Dexes               Dexes
# 1                 Total            ethereum            ethereum
# 2                   TVL         Tokens(USD)         Tokens(USD)
# 3                   NaN                WBTC                 MKR
# 4     16911034.80409584  143.63434717201235   3174.054475224288
# ..                  ...                 ...                 ...
# 753  149317293.68511936     632397.79419665   12709.51376277181
# 754  140402690.54627365   613739.8324038315   11805.72942344325
# 755  141568688.84341565   630010.5414320339  11613.814724227803
# 756  139202235.88281885    613406.861531592  11359.602133309669
# 757  133931070.80164133    595425.217255968  11043.091650688844
#
#              Loopring.4          Loopring.5          Loopring.6  \
# 0                 Dexes               Dexes               Dexes
# 1              ethereum            ethereum            ethereum
# 2           Tokens(USD)         Tokens(USD)         Tokens(USD)
# 3                  USDT                LINK                WETH
# 4    1032792.3967412934  165192.59075325352   5582609.946434269
# ..                  ...                 ...                 ...
# 753  2069670.6588347787  123824.02097254105  31341674.024221398
# 754       2065557.45217  118258.89643444933  29164932.204454284
# 755  2067304.5128365627  111920.83793273375   29858368.36643697
# 756  2063327.8672692582  107901.58132188972   29058246.77377619
# 757  2065774.6336877649  103109.39074742183  27238670.856880274
#
#              Loopring.7         Loopring.8          Loopring.9  \
# 0                 Dexes              Dexes               Dexes
# 1              ethereum           ethereum            ethereum
# 2           Tokens(USD)        Tokens(USD)         Tokens(USD)
# 3                  USDC                LRC                 DAI
# 4     139577.2067713867  9849870.431476103  137674.54309713593
# ..                  ...                ...                 ...
# 753   22339280.40575631  92252254.86035335   545482.4070215533
# 754  22197397.722677622  85806747.08823386   424251.6204761444
# 755  21973057.153689355  86473913.79905221   442499.8173115533
# 756  21913463.941097446  84992471.49613716   442057.7595520013
# 757  21979857.096567366   81495280.8446493   441909.6702025514
#
#                                            Loopring.10         Loopring.11  \
# 0                                                Dexes               Dexes
# 1                                             ethereum               Total
# 2                                          Tokens(USD)         Tokens(USD)
# 3    UNKNOWN (0x9f8F72aA9304c8B593d555F12eF6589cC3A...                WBTC
# 4                                                  NaN  143.63434717201235
# ..                                                 ...                 ...
# 753                                                NaN     632397.79419665
# 754                                                NaN   613739.8324038315
# 755                                                NaN   630010.5414320339
# 756                                                NaN    613406.861531592
# 757                                                NaN    595425.217255968
#
#             Loopring.12         Loopring.13         Loopring.14  \
# 0                 Dexes               Dexes               Dexes
# 1                 Total               Total               Total
# 2           Tokens(USD)         Tokens(USD)         Tokens(USD)
# 3                   MKR                USDT                LINK
# 4     3174.054475224288  1032792.3967412934  165192.59075325352
# ..                  ...                 ...                 ...
# 753   12709.51376277181  2069670.6588347787  123824.02097254105
# 754   11805.72942344325       2065557.45217  118258.89643444933
# 755  11613.814724227803  2067304.5128365627  111920.83793273375
# 756  11359.602133309669  2063327.8672692582  107901.58132188972
# 757  11043.091650688844  2065774.6336877649  103109.39074742183
#
#             Loopring.15         Loopring.16        Loopring.17  \
# 0                 Dexes               Dexes              Dexes
# 1                 Total               Total              Total
# 2           Tokens(USD)         Tokens(USD)        Tokens(USD)
# 3                  WETH                USDC                LRC
# 4     5582609.946434269   139577.2067713867  9849870.431476103
# ..                  ...                 ...                ...
# 753  31341674.024221398   22339280.40575631  92252254.86035335
# 754  29164932.204454284  22197397.722677622  85806747.08823386
# 755   29858368.36643697  21973057.153689355  86473913.79905221
# 756   29058246.77377619  21913463.941097446  84992471.49613716
# 757  27238670.856880274  21979857.096567366   81495280.8446493
#
#             Loopring.18                                        Loopring.19  \
# 0                 Dexes                                              Dexes
# 1                 Total                                              Total
# 2           Tokens(USD)                                        Tokens(USD)
# 3                   DAI  UNKNOWN (0x9f8F72aA9304c8B593d555F12eF6589cC3A...
# 4    137674.54309713593                                                NaN
# ..                  ...                                                ...
# 753   545482.4070215533                                                NaN
# 754   424251.6204761444                                                NaN
# 755   442499.8173115533                                                NaN
# 756   442057.7595520013                                                NaN
# 757   441909.6702025514                                                NaN
#
#      Loopring.20         Loopring.21     Loopring.22         Loopring.23  \
# 0          Dexes               Dexes           Dexes               Dexes
# 1       ethereum            ethereum        ethereum            ethereum
# 2         Tokens              Tokens          Tokens              Tokens
# 3           WBTC                 MKR            USDT                LINK
# 4     0.01252044                   5  1032302.709466  10568.256487273999
# ..           ...                 ...             ...                 ...
# 753  31.58672365  18.596385582892147  2067603.055779  15458.679272477037
# 754  31.58672365  18.596385582892147   2065557.45217  15458.679272477037
# 755   32.2783878  18.596385582892147  2065239.273563  15458.679272477037
# 756   32.2783878  18.596385582892147  2064638.912979  15458.679272477037
# 757   32.2783878  18.596385582892147  2063710.922765  15458.679272477037
#
#             Loopring.24      Loopring.25         Loopring.26  \
# 0                 Dexes            Dexes               Dexes
# 1              ethereum         ethereum            ethereum
# 2                Tokens           Tokens              Tokens
# 3                  WETH             USDC                 LRC
# 4      13996.5406780803        139558.43   51650115.45784983
# ..                  ...              ...                 ...
# 753   21584.28303528876  22316963.442314  280014736.03482527
# 754   21702.68201903075  22220862.953957  279810692.91147804
# 755  21829.962907825855  21929198.756177   279831836.0210219
# 756   21767.94448597747  21933664.846421   279854829.7216915
# 757  21904.489559380047   21957899.19737   279448480.2425318
#
#             Loopring.27                                        Loopring.28  \
# 0                 Dexes                                              Dexes
# 1              ethereum                                           ethereum
# 2                Tokens                                             Tokens
# 3                   DAI  UNKNOWN (0x9f8F72aA9304c8B593d555F12eF6589cC3A...
# 4      136146.871653989                                                NaN
# ..                  ...                                                ...
# 753   544937.4695520013                                                NaN
# 754  424937.46955200133                                                NaN
# 755   442057.7595520013                                                NaN
# 756   442057.7595520013                                                NaN
# 757   442057.7595520013                                                NaN
#
#      Loopring.29         Loopring.30     Loopring.31         Loopring.32  \
# 0          Dexes               Dexes           Dexes               Dexes
# 1          Total               Total           Total               Total
# 2         Tokens              Tokens          Tokens              Tokens
# 3           WBTC                 MKR            USDT                LINK
# 4     0.01252044                   5  1032302.709466  10568.256487273999
# ..           ...                 ...             ...                 ...
# 753  31.58672365  18.596385582892147  2067603.055779  15458.679272477037
# 754  31.58672365  18.596385582892147   2065557.45217  15458.679272477037
# 755   32.2783878  18.596385582892147  2065239.273563  15458.679272477037
# 756   32.2783878  18.596385582892147  2064638.912979  15458.679272477037
# 757   32.2783878  18.596385582892147  2063710.922765  15458.679272477037
#
#             Loopring.33      Loopring.34         Loopring.35  \
# 0                 Dexes            Dexes               Dexes
# 1                 Total            Total               Total
# 2                Tokens           Tokens              Tokens
# 3                  WETH             USDC                 LRC
# 4      13996.5406780803        139558.43   51650115.45784983
# ..                  ...              ...                 ...
# 753   21584.28303528876  22316963.442314  280014736.03482527
# 754   21702.68201903075  22220862.953957  279810692.91147804
# 755  21829.962907825855  21929198.756177   279831836.0210219
# 756   21767.94448597747  21933664.846421   279854829.7216915
# 757  21904.489559380047   21957899.19737   279448480.2425318
#
#             Loopring.36                                        Loopring.37
# 0                 Dexes                                              Dexes
# 1                 Total                                              Total
# 2                Tokens                                             Tokens
# 3                   DAI  UNKNOWN (0x9f8F72aA9304c8B593d555F12eF6589cC3A...
# 4      136146.871653989                                                NaN
# ..                  ...                                                ...
# 753   544937.4695520013                                                NaN
# 754  424937.46955200133                                                NaN
# 755   442057.7595520013                                                NaN
# 756   442057.7595520013                                                NaN
# 757   442057.7595520013                                                NaN
#
# [758 rows x 41 columns]

# %%
lma.iloc[:,4]
# Out:
# 0                   Dexes
# 1                   Total
# 2                     TVL
# 3                     NaN
# 4       16911034.80409584
#               ...
# 753    149317293.68511936
# 754    140402690.54627365
# 755    141568688.84341565
# 756    139202235.88281885
# 757    133931070.80164133
# Name: Loopring.1, Length: 758, dtype: object

# %%
#Just eth currently can take total by changing the header
lma.iloc[-183:, 4].astype(float).mean()
# Out:
# 220545935.44076264

# %%
endpoint = "https://saberqltest.aleph.cloud/"

# %%
query = """{pools {
  ammId    
  name    
  coin {
    chainId
    address      
    name     
    decimals  
    symbol      
    logoURI    }    
  pc {      
    chainId      
    address      
    name      
    decimals      
    symbol      
    logoURI   }    
  lp {      
    chainId      
    address    
    name     
    decimals      
    symbol   
    logoURI    }  
  stats {   
    tvl_pc    
    tvl_coin
    tvl_usd
    price      
    vol24h    } }}"""

# %%
request = requests.post(endpoint, json={'query':query})
data = request.json()

# %%
df= pd.json_normalize(data['data']['pools'])

# %%
df
# Out:
#                                             ammId              name  \
# 0    3nesbuhAwCMGtsyypYtg4oRPwJ3FmHnytC5bqskhPh1x         TRYB-TRYB
# 1    4EFeyTtMZZnAv3ZPs2jvps1T1J1JykbpyizrWjBQcA1S  wLUNA-srenLUNA-9
# 2    4xeRVccqvUgiV6VeF6NkWqkAYeewcJPRWFVginvJw1n4      wDAI-sUSDC-9
# 3    7dwD9TF6uikvHXxPFK9AsSim54yJoujQjY9vU6gNFumk        stSOL-mSOL
# 4    7oAd7xG4m3oC2qeWB1szghTebAZyyGPAFDJ4wwwbRSNi         wUST-USDC
# ..                                            ...               ...
# 106   oKQqupM9E7SSLAFDLxr7mdsXP7znck9qRbVWc6Yyj7Q        wUSDK-USDC
# 107   okgoAkj7GvBT1Q54j6Qvm6AZPritriGTjcEpkPhdWqf      USDK-sUSDC-9
# 108   parEAJhzYzHW87y9VoZAQ22dzQ2MD2ekEtTReaxbMcz       pSOL-prtSOL
# 109   vEnkoSUkpnbRrPgBz9DfcVxNz67zjwMYBZraAvDDNSf       weUSDT-USDT
# 110   wrmcMSHFi3sWpAEy4rGDvQb3ezh3PhXoV2xNjgLBkKU         ETH-whETH
#
#      coin.chainId                                  coin.address  \
# 0           101.0  9QBTKuSCDaJjtxYnYcVzoiKENMdJ5DRei5ZUCEeWyZnj
# 1           101.0  2Xf2yAXJfg82sWwdLUo2x9mZXy6JCdszdMZkcF1Hf4KV
# 2           101.0  FYpdBuyAHSbdaAyD1sKkxyLWbAP8uUW9h6uvdhK74ij1
# 3           101.0  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj
# 4           101.0  CXLBjMMcwkc17GfJtBos6rQCo1ypeH6eDbB82Kby4MRm
# ..            ...                                           ...
# 106         101.0  43m2ewFV5nDepieFjT9EmAQnc1HRtAF247RBpLGFem5F
# 107           NaN  2kycGCD8tJbrjJJqWN2Qz5ysN9iB4Bth3Uic4mSB7uak
# 108         101.0  9EaLkQrbjmbbuZG9Wdpo8qfNUEjHATJFSycEmw6f1rGX
# 109         101.0  Dn4noZ5jgGfkntzcQSUZ8czkreiZ1ForXYoV2H8Dm7S1
# 110         101.0   SL819j8K9FuFPL84UepVcFkEZqDUUvVzwDmJjCHySYj
#
#                                              coin.name  coin.decimals  \
# 0                                    BiLira (Wormhole)              6
# 1                        Wrapped LUNA Token (Wormhole)              9
# 2                            Dai Stablecoin (Wormhole)              9
# 3                                      Lido Staked SOL              9
# 4                               Wrapped UST (Wormhole)              9
# ..                                                 ...            ...
# 106                                    USDK (Wormhole)              8
# 107                                               USDK              9
# 108                                  pSOL (Parrot SOL)              9
# 109                                USDT (ETH Wormhole)              6
# 110  Saber Wrapped Wrapped Ethereum (Sollet) (8 dec...              8
#
#     coin.symbol                                       coin.logoURI  \
# 0          TRYB  https://cdn.jsdelivr.net/gh/saber-hq/spl-token...
# 1         wLUNA  https://raw.githubusercontent.com/solana-labs/...
# 2          wDAI  https://raw.githubusercontent.com/solana-labs/...
# 3         stSOL  https://cdn.jsdelivr.net/gh/saber-hq/spl-token...
# 4          wUST  https://raw.githubusercontent.com/solana-labs/...
# ..          ...                                                ...
# 106       wUSDK  https://spl-token-icons.static-assets.ship.cap...
# 107        USDK                                               None
# 108        pSOL  https://raw.githubusercontent.com/solana-labs/...
# 109      weUSDT  https://spl-token-icons.static-assets.ship.cap...
# 110      sETH-8  https://spl-token-icons.static-assets.ship.cap...
#
#      pc.chainId                                    pc.address  \
# 0         101.0  A94X2fRy3wydNShU4dRaDyap2UuoeWJGWyATtyp61WZf
# 1           NaN   KUANeD8EQvwpT1W7QZDtDqctLEh2FfSTy5pThE9CogT
# 2           NaN  JEFFSQ3s8T3wKsvp4tnRAsUBW7Cqgnf8ukBZC4C8XBm1
# 3         101.0   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 4           NaN  JEFFSQ3s8T3wKsvp4tnRAsUBW7Cqgnf8ukBZC4C8XBm1
# ..          ...                                           ...
# 106       101.0  88881Hu2jGMfCs9tMu5Rr7Ah7WBNBuXqde4nR5ZmKYYy
# 107         NaN  JEFFSQ3s8T3wKsvp4tnRAsUBW7Cqgnf8ukBZC4C8XBm1
# 108         NaN  BdZPG9xWrG3uFrx2KrUW1jT4tZ9VKPDWknYihzoPRJS3
# 109       101.0  Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB
# 110       101.0  7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
#
#                                  pc.name  pc.decimals   pc.symbol  \
# 0                                 BiLira            6        TRYB
# 1     Saber Wrapped renLUNA (9 decimals)            9  srenLUNA-9
# 2    Saber Wrapped USD Coin (9 decimals)            9     sUSDC-9
# 3             Marinade staked SOL (mSOL)            9        mSOL
# 4    Saber Wrapped USD Coin (9 decimals)            9     sUSDC-9
# ..                                   ...          ...         ...
# 106  Saber Wrapped USD Coin (8 decimals)            8     sUSDC-8
# 107  Saber Wrapped USD Coin (9 decimals)            9     sUSDC-9
# 108                Parrot Stake Pool SOL            9      prtSOL
# 109                                 USDT            6        USDT
# 110                     Ether (Wormhole)            8       whETH
#
#                                             pc.logoURI  lp.chainId  \
# 0    https://cdn.jsdelivr.net/gh/saber-hq/spl-token...       101.0
# 1                                                 None         NaN
# 2                                                 None         NaN
# 3    https://cdn.jsdelivr.net/gh/saber-hq/spl-token...       101.0
# 4                                                 None         NaN
# ..                                                 ...         ...
# 106  https://spl-token-icons.static-assets.ship.cap...       101.0
# 107                                               None         NaN
# 108                                               None         NaN
# 109  https://spl-token-icons.static-assets.ship.cap...       101.0
# 110  https://spl-token-icons.static-assets.ship.cap...       101.0
#
#                                        lp.address               lp.name  \
# 0     Lirav2gsqs7jL1PFRUBp8uKACT8LYjDBV8c6nzchoer    Saber TRYB-TRYB LP
# 1     LUNkiLcb2wxcqULmJvMjuM6YQhpFBadG5KZBe7qBpSE      wLUNA-srenLUNA-9
# 2    Daimhb91DY4e3aVaa7YCW5GgwaMT9j1ALSi2GriBvDNh          wDAI-sUSDC-9
# 3    4FKZsej5FonJWj24xhgG13wV4FSMQqTDwABBQaoQNMZF   Saber stSOL-mSOL LP
# 4     UST32f2JtPGocLzsL41B3VBBoJzTm1mK1j3rwyM3Wgc             wUST-USDC
# ..                                            ...                   ...
# 106   USDKKmk1anWU1aEn6GJ6skL3ZvcB9CBAWVkmPGQEHtz   wUSDK-USDC Saber LP
# 107   uSdKg2Cs5bCtFSeNXs7aRVNzZJauX58eCkdsfssxTdW          USDK-sUSDC-9
# 108   PSopTFPXzTRysj2H6W8oTvYBZmJHtRcVaQaDkckifAy           pSOL-prtSOL
# 109   USDTJZL2vH92K5QeCvQTTzvMXUYAdvk3v46CwZyfsue  weUSDT-USDT Saber LP
# 110   WTHPuMavN9HBvgUafjrL65WqQytQHDwnTAmdFB9whXA    ETH-whETH Saber LP
#
#      lp.decimals         lp.symbol  \
# 0              6         TRYB-TRYB
# 1              9  wLUNA-srenLUNA-9
# 2              9      wDAI-sUSDC-9
# 3              9        stSOL-mSOL
# 4              9         wUST-USDC
# ..           ...               ...
# 106            8        wUSDK-USDC
# 107            9      USDK-sUSDC-9
# 108            9       pSOL-prtSOL
# 109            6       weUSDT-USDT
# 110            8         ETH-whETH
#
#                                             lp.logoURI  stats.tvl_pc  \
# 0    https://cdn.jsdelivr.net/gh/saber-hq/spl-token...      0.000000
# 1                                                 None   1539.521871
# 2                                                 None   5892.514602
# 3    https://cdn.jsdelivr.net/gh/saber-hq/spl-token...      0.003414
# 4                                                 None   1333.062825
# ..                                                 ...           ...
# 106      https://registry.saber.so/token-icons/slp.png  17357.182700
# 107                                               None    795.935829
# 108                                               None    587.221322
# 109      https://registry.saber.so/token-icons/slp.png   3146.734712
# 110      https://registry.saber.so/token-icons/slp.png     20.344256
#
#      stats.tvl_coin  stats.tvl_usd  stats.price  stats.vol24h
# 0          0.000000       0.000000     0.999611      0.000000
# 1          0.182031       0.000000     3.984003      0.000000
# 2       7968.916379   11785.029203     0.997858      0.000000
# 3          0.003746       0.000000     0.985754      0.000000
# 4     299561.043016    2666.125651     0.035571     65.796138
# ..              ...            ...          ...           ...
# 106    18781.329125   34714.365399     0.995969      0.000000
# 107     8347.955140    1591.871658     0.907005      0.000000
# 108     2569.122423       0.000000     0.940964      5.711857
# 109     4489.792571    6293.469424     1.000022    399.094737
# 110       29.580428       0.000000     0.999197     53.465665
#
# [111 rows x 25 columns]

# %%
df['stats.tvl_usd'].astype(float).max()/df['stats.tvl_usd'].astype(float).sum()
# Out:
# 0.25398253095490425

# %%
df['stats.tvl_usd'].astype(float).nlargest(10).sum()/df['stats.tvl_usd'].astype(float).sum()
# Out:
# 0.9720466898714312

# %%
#Liquidity Pools with > $1mn TVL
len(df.loc[df['stats.tvl_usd'].astype(float) > 1000000])
# Out:
# 5

# %%
headers = {# Chrome 83 Mac
    "Connection": "keep-alive",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Sec-Fetch-Site": "none",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Dest": "document",
    "Referer": "https://www.google.com/",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8"}

# %%
#active users
url = "https://brew.hellomoon.io/api/aggregations/defi-program-by-active-user-count?timeRangeFilter=all&protocolFilter=aeb145d8f590503f3e6cab0b0a6d97fb"

# %%
resp = requests.get(url, headers = headers)

# %%
data =resp.json()

# %%
df = pd.DataFrame(data['data'])

# %%
df['y'].head(183).mean()
# Out:
# 1497.950819672131

# %%
url = "https://nomics.com/data/exchange-volume-history?convert=USD&exchange=loopring&interval=all"

# %%
resp = requests.get(url)

# %%
data = resp.json()

# %%
df = pd.DataFrame(data['items'])

# %%
df['volume'].astype(float).tail(183).mean()
# Out:
# 4698799.027322404

# %%
data
# Out:
# {'items': [], 'items_total': 0}

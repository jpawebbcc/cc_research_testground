# %% [markdown]
# ## Messari standardised subgraphs
#
# https://github.com/messari/subgraphs
#
# ### TraderJoe

# %%
import pandas as pd
import numpy as np
import time
import requests
import datetime as dt

# %%
endpoint = 'https://api.thegraph.com/subgraphs/name/messari/trader-joe-avalanche'

# %% [markdown]
# #Check if subgraph is up to date

# %%
query = """{
  _meta{
    block{
      timestamp
  		hash
      number
    }
    hasIndexingErrors
    deployment
  }
}"""

# %%
request = requests.post(endpoint, json={'query':query})
data = request.json()

# %%
#Check if it is ok to run i.e. within 5 days of today
int(data['data']['_meta']['block']['timestamp'], base = 0) > (dt.datetime.today().timestamp() - 3600*24*5)
# Out:
# False

# %%
query = """{
  financialsDailySnapshots(first: 183, orderBy: timestamp, orderDirection: desc){
    id
    protocol{
      name
    }
    dailyVolumeUSD
    dailyTotalRevenueUSD
    dailySupplySideRevenueUSD
    dailyProtocolSideRevenueUSD
    timestamp
    blockNumber
  }
}
"""

# %%
request = requests.post(endpoint, json={'query':query})
data = request.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /home/luke/Code/Research/cc_research_testground/DEX_data_collection/TraderJoe.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/luke/Code/Research/cc_research_testground/DEX_data_collection/TraderJoe.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> request = requests.post(endpoint, json={'query':query})
# ----> <a href='vscode-notebook-cell:/home/luke/Code/Research/cc_research_testground/DEX_data_collection/TraderJoe.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> data = request.json()
#
# File /usr/lib/python3/dist-packages/requests/models.py:897, in Response.json(self, **kwargs)
#     891         except UnicodeDecodeError:
#     892             # Wrong UTF codec detected; usually because it's not UTF-8
#     893             # but some other 8-bit codec.  This is an RFC violation,
#     894             # and the server didn't bother to tell us what codec *was*
#     895             # used.
#     896             pass
# --> 897 return complexjson.loads(self.text, **kwargs)
#
# File /usr/lib/python3/dist-packages/simplejson/__init__.py:518, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     467 """Deserialize ``s`` (a ``str`` or ``unicode`` instance containing a JSON
#     468 document) to a Python object.
#     469
#    (...)
#     512
#     513 """
#     514 if (cls is None and encoding is None and object_hook is None and
#     515         parse_int is None and parse_float is None and
#     516         parse_constant is None and object_pairs_hook is None
#     517         and not use_decimal and not kw):
# --> 518     return _default_decoder.decode(s)
#     519 if cls is None:
#     520     cls = JSONDecoder
#
# File /usr/lib/python3/dist-packages/simplejson/decoder.py:370, in JSONDecoder.decode(self, s, _w, _PY3)
#     368 if _PY3 and isinstance(s, bytes):
#     369     s = str(s, self.encoding)
# --> 370 obj, end = self.raw_decode(s)
#     371 end = _w(s, end).end()
#     372 if end != len(s):
#
# File /usr/lib/python3/dist-packages/simplejson/decoder.py:400, in JSONDecoder.raw_decode(self, s, idx, _w, _PY3)
#     398     elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399         idx += 3
# --> 400 return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df = pd.json_normalize(data['data']['financialsDailySnapshots'])

# %%
df
# Out:
#         id                        dailyVolumeUSD  \
# 0    18986    127735336.336453941703130776123734
# 1    18985   306996677.2010667221524070573994513
# 2    18984   387934018.2827785139481035305327708
# 3    18983   360550584.6087715717571322690715548
# 4    18982   407431063.7053110019582815255118556
# ..     ...                                   ...
# 175  18811   427285.1154816336711009923065110042
# 176  18810    10912.3576246905298217520937025483
# 177  18809   47.17587494342310505425464539125728
# 178  18808  0.4320268541150868638565432556812733
# 179  18807  0.1497974277296778666741543326570142
#
#                         dailyTotalRevenueUSD  \
# 0        383206.0090093618251093923283711827
# 1        920990.0316032001664572211721983718
# 2        1163802.054848335541844310591598271
# 3        1081651.753826314715271396807214645
# 4        1222293.191115933005874844576535434
# ..                                       ...
# 175      1281.855346444901013302976919533023
# 176      32.73707287407158946525628110764493
# 177     0.1415276248302693151627639361737718
# 178    0.00129608056234526059156962976704382
# 179  0.0004493922831890336000224629979710423
#
#                    dailySupplySideRevenueUSD  \
# 0        319338.3408411348542578269403093144
# 1        767491.6930026668053810176434986736
# 2        969835.0457069462848702588263319652
# 3        901376.4615219289293928306726788964
# 4        1018577.659263277504895703813779583
# ..                                       ...
# 175      1068.212788704084177752480766277518
# 176      27.28089406172632455438023425637081
# 177     0.1179396873585577626356366134781432
# 178   0.001080067135287717159641358139203183
# 179  0.0003744935693241946666853858316425353
#
#                   dailyProtocolSideRevenueUSD   timestamp blockNumber  \
# 0         63867.66816822697085156538806186321  1640458041     8708146
# 1         153498.3386005333610762035286997304  1640390396     8674854
# 2         193967.0091413892569740517652664077  1640303999     8632300
# 3         180275.2923043857858785661345357701  1640217598     8589431
# 4         203715.5318526555009791407627559178  1640131199     8546800
# ..                                        ...         ...         ...
# 175        213.642557740816835550496153255505  1625356729     2553448
# 176       5.456178812345264910876046851274159  1625270332     2540256
# 177     0.02358793747171155252712732269562864  1625155633     2529146
# 178   0.0002160134270575434319282716278406367  1625078763     2521811
# 179  0.00007489871386483893333707716632850708  1624986883     2511529
#
#     protocol.name
# 0      Trader Joe
# 1      Trader Joe
# 2      Trader Joe
# 3      Trader Joe
# 4      Trader Joe
# ..            ...
# 175    Trader Joe
# 176    Trader Joe
# 177    Trader Joe
# 178    Trader Joe
# 179    Trader Joe
#
# [180 rows x 8 columns]

# %%
df['dailyVolumeUSD'].astype(float).mean()
# Out:
# 215445844.412662

# %% [markdown]
# 6-Month Average TVL

# %%
#DefiLlama https://defillama.com/protocols/dexes 
lma = pd.read_csv("https://api.llama.fi/dataset/trader-joe.csv")

# %%
lma
# Out:
#      Unnamed: 0        Date     Timestamp          Trader Joe  \
# 0           NaN         NaN           NaN               Dexes
# 1           NaN         NaN           NaN   avalanche-staking
# 2           NaN         NaN           NaN                 TVL
# 3           NaN         NaN           NaN                 NaN
# 4           NaN  10/08/2021  1.628554e+09                 NaN
# ..          ...         ...           ...                 ...
# 350         NaN  24/07/2022  1.658621e+09  2809204.7633998194
# 351         NaN  25/07/2022  1.658707e+09  2643335.3311571325
# 352         NaN  26/07/2022  1.658794e+09   2518358.633168714
# 353         NaN  27/07/2022  1.658880e+09   2430099.162424295
# 354         NaN  28/07/2022  1.658966e+09  2735880.3314757505
#
#            Trader Joe.1        Trader Joe.2        Trader Joe.3  \
# 0                 Dexes               Dexes               Dexes
# 1             avalanche               Total            borrowed
# 2                   TVL                 TVL                 TVL
# 3                   NaN                 NaN                 NaN
# 4     27185720.15206458   27185720.15206458                 NaN
# ..                  ...                 ...                 ...
# 350   222211233.3070865   222211233.3070865   9946029.249152992
# 351  216245723.53293616  216245723.53293616  10019901.713273589
# 352  206089405.17436627  206089405.17436627   9212054.950338708
# 353   198462065.5869773   198462065.5869773     9135820.9186153
# 354   212654847.1970699   212654847.1970699   9590756.849194739
#
#            Trader Joe.4        Trader Joe.5        Trader Joe.6  ...  \
# 0                 Dexes               Dexes               Dexes  ...
# 1               staking  avalanche-borrowed   avalanche-staking  ...
# 2                   TVL                 TVL         Tokens(USD)  ...
# 3                   NaN                 NaN                 JOE  ...
# 4                   NaN                 NaN                 NaN  ...
# ..                  ...                 ...                 ...  ...
# 350  2809204.7633998194   9946029.249152992  2809204.7633998194  ...
# 351  2643335.3311571325  10019901.713273589  2643335.3311571325  ...
# 352   2518358.633168714   9212054.950338708   2518358.633168714  ...
# 353   2430099.162424295     9135820.9186153   2430099.162424295  ...
# 354  2735880.3314757505   9590756.849194739  2735880.3314757505  ...
#
#         Trader Joe.1412     Trader Joe.1413     Trader Joe.1414  \
# 0                 Dexes               Dexes               Dexes
# 1    avalanche-borrowed  avalanche-borrowed  avalanche-borrowed
# 2                Tokens              Tokens              Tokens
# 3                  USDC               WAVAX                 DAI
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 350       462893.510858   48343.95510703475                 NaN
# 351       453549.530282    55151.4205318807                 NaN
# 352       465937.279357   35022.41814588823                 NaN
# 353       455608.890411  35932.949910587144                 NaN
# 354       532993.759792   33575.80393902463                 NaN
#
#         Trader Joe.1415     Trader Joe.1416     Trader Joe.1417  \
# 0                 Dexes               Dexes               Dexes
# 1    avalanche-borrowed  avalanche-borrowed  avalanche-borrowed
# 2                Tokens              Tokens              Tokens
# 3                   JOE              WETH.E              USDT.E
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 350                   0  210.53588266210934      1324316.093457
# 351                   0  220.54083664581327      1324187.204571
# 352                   0  221.55728110625924      1332164.320055
# 353                   0  223.79656607415373      1332169.882177
# 354                   0  227.79448166794376      1332418.700956
#
#         Trader Joe.1418     Trader Joe.1419     Trader Joe.1420  \
# 0                 Dexes               Dexes               Dexes
# 1    avalanche-borrowed  avalanche-borrowed  avalanche-borrowed
# 2                Tokens              Tokens              Tokens
# 3                LINK.E              USDC.E               DAI.E
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 350  3711.1179321779673      1782369.238375   69432.13918254818
# 351  3707.8421095983067      1761469.429347   68991.32557920115
# 352  3707.9347823749185      1674778.326781   69542.64604818421
# 353   3838.764079751082      1656873.664883   69787.35687272168
# 354  3773.9111114690186      1627691.033989   69487.20834822605
#
#         Trader Joe.1421
# 0                 Dexes
# 1    avalanche-borrowed
# 2                Tokens
# 3                WBTC.E
# 4                   NaN
# ..                  ...
# 350        202.49792437
# 351        202.55098188
# 352        202.64596009
# 353        202.71210824
# 354        202.79438009
#
# [355 rows x 1425 columns]

# %%
lma.iloc[:,5]
# Out:
# 0                   Dexes
# 1                   Total
# 2                     TVL
# 3                     NaN
# 4       27185720.15206458
#               ...
# 350     222211233.3070865
# 351    216245723.53293616
# 352    206089405.17436627
# 353     198462065.5869773
# 354     212654847.1970699
# Name: Trader Joe.2, Length: 355, dtype: object

# %%
#Just eth currently can take total by changing the header
lma.iloc[-183:, 5].astype(float).mean()
# Out:
# 861488917.574098

# %% [markdown]
# Largest Pool Concentration

# %%
df = pd.DataFrame()
ts = 0

while True:
    sl = len(df)
    query = """
{
  liquidityPools(first:1000, orderBy: createdTimestamp, orderDirection: asc, where: {createdTimestamp_gt: """+f'"{ts}"'+"""}){
    id
    name
    totalValueLockedUSD
    cumulativeVolumeUSD
    createdTimestamp
    createdBlockNumber
  }
}
"""
    request = requests.post(endpoint, json={'query':query})
    data = request.json()

    pool = pd.json_normalize(data['data']['liquidityPools'])
    df = df.append(pool)
    df.drop_duplicates(inplace=True)
    if len(df) == sl:
      break
    ts = df['createdTimestamp'].max()
# Out:
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)
# /tmp/ipykernel_38884/2291472997.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pool)

# %%
df
# Out:
#                                             id  \
# 0   0xe4b9865c0866346ba3613ec122040a365637fb46
# 1   0x43b9c8dec26c2d21146466caacabf94fdbeac473
# 2   0x454e67025631c065d3cfad6d71e6892f74487a15
# 3   0xc992ab46428a5a2edeb8f44d946ce5642f97ef71
# 4   0xbeb0b5fbd99b8e7498a4063cb419646922f6eef8
# ..                                         ...
# 18  0xfc09642025735b8a2939e175106a76ba8c4cf606
# 19  0xc530f9bede2a26728a7a23a26edcd5d43fb4194d
# 20  0xfc8552e35a31b4a691d21625b7708f4ca1b8af49
# 21  0x06bcfd685359e6793a9b3c2b198c0058fd7b9172
# 22  0x7a7ba89427724cf649ebf8238439dedd3aa95b9a
#
#                                        name  \
# 0        Trader Joe Wrapped AVAX/Tether USD
# 1    Trader Joe Wrapped AVAX/Dai Stablecoin
# 2          Trader Joe JoeToken/Wrapped AVAX
# 3             Trader Joe Wrapped AVAX/Ether
# 4       Trader Joe Wrapped BTC/Wrapped AVAX
# ..                                      ...
# 18  Trader Joe Marry Christmas/Wrapped AVAX
# 19   Trader Joe Wrapped AVAX/Floki Infinity
# 20      Trader Joe Wrapped AVAX/Black Magic
# 21   Trader Joe ArmstrongNODES/Wrapped AVAX
# 22       Trader Joe APOCALYPSE/Wrapped AVAX
#
#                      totalValueLockedUSD                  cumulativeVolumeUSD  \
# 0    6484.179900709220070627921160113411  9325120.427742135894129431509903297
# 1    134.2678484908605515725797764843462  2714468.112285384520330109034095196
# 2    82647759.06534404531383957243697566  2297356558.370547501916177531931797
# 3    411.9885602769737286802318305746771  4342702.358870155756745066755522081
# 4    347.7439464085046324372682710349888   1111589.29238632167115068817186826
# ..                                   ...                                  ...
# 18  0.8412608762829240736896787671660581                                    0
# 19   201680.3722027129983677527102982412  157824.5325832867303445585580791449
# 20  0.2070004302992343170962491725725843                                    0
# 21   2.835202510311528152176208529937987                                    0
# 22   5411.837407806168437581314256572662                                    0
#
#    createdTimestamp createdBlockNumber
# 0        1624941631            2504194
# 1        1624941782            2504226
# 2        1625028033            2516404
# 3        1625029067            2516545
# 4        1625029156            2516553
# ..              ...                ...
# 18       1640455902            8707096
# 19       1640456320            8707302
# 20       1640457731            8707996
# 21       1640457884            8708071
# 22       1640458208            8708228
#
# [7023 rows x 6 columns]

# %%
df['totalValueLockedUSD'].astype(float).max()/df['totalValueLockedUSD'].astype(float).sum()
# Out:
# 0.2894597157869572

# %%
df['totalValueLockedUSD'].astype(float).nlargest(10).sum()/df['totalValueLockedUSD'].astype(float).sum()
# Out:
# 0.84522224004488

# %% [markdown]
# Liquidity Pools with > $1mn TVL

# %%
len(df.loc[df['totalValueLockedUSD'].astype(float) > 1000000])
# Out:
# 70

# %% [markdown]
# Monthly Active Users

# %%
query = """{
  usageMetricsDailySnapshots(first: 183, orderBy: timestamp, orderDirection: desc){
    timestamp
    blockNumber
    id
    dailyActiveUsers
    dailySwapCount
    dailyDepositCount
    dailyWithdrawCount 
  }
}
"""

# %%
request = requests.post(endpoint, json={'query':query})
data = request.json()

# %%
df = pd.json_normalize(data['data']['usageMetricsDailySnapshots'])

# %%
df['date'] = df['timestamp'].astype(int).apply(lambda x: dt.datetime.fromtimestamp(x))

# %%
monthactiveusers = []
for i in range(len(df['date'].dt.month.unique())):
    monthactiveusers.append(df['dailyActiveUsers'].loc[df['date'].dt.month == df['date'].dt.month.unique()[i]].astype(float).sum())

# %%
np.mean(monthactiveusers) #can chart this easy
# Out:
# 394612.0

# %% [markdown]
# Implied slippage
